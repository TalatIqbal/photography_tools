# %%
import os, PIL
import numpy as np
from PIL import Image
import datetime
import time
import traceback
import cv2
from matplotlib import pyplot as plt
import cv2

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
im = np.array(Image.open('../data//abc.png'))

print(type(im))
# <class 'numpy.ndarray'>

print(im.dtype)
# uint8

print(im.shape)
# Out:
# <class 'numpy.ndarray'>
# uint8
# (761, 1144, 4)

# %%
filename = '../data/abc.png'
  
img = cv2.imread(filename) 
  
# Output img with window name as 'image'
cv2.imshow('image', img)

# %%
filename = '../data/abc.png'
img = cv2.imread(filename) 
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(type(img))

op_img = img.copy()
op_img[:, :, 0] = 0.0
op_img[:, :, 1] = 0.0
op_file = '../data/abc_red.jpg'
cv2.imwrite(op_file, op_img)


op_img = img.copy()
op_img[:, :, 2] = 0.0
op_img[:, :, 1] = 0.0
op_file = '../data/abc_green.jpg'
cv2.imwrite(op_file, op_img)

op_img = img.copy()
op_img[:, :, 0] = 0.0
op_img[:, :, 2] = 0.0
op_file = '../data/abc_blue.jpg'
cv2.imwrite(op_file, op_img)

plt.imshow(img)
plt.title('my picture')
plt.show()
# Out:
# <class 'numpy.ndarray'>
